# %% [markdown]
# # House Price Prediction

# %% [markdown]
# ## In this notebook we will predicit the house price based on some features

# %% [markdown]
# ## Importing Libraries
# <b>numpy</b> for mathematical operations on data<br>
# <b>pandas</b> for managing data<br>
# <b>matplotlib.plt</b> for plotting stastical graphs<br>
# <b>seaborn</b> for plotting interactive graphs<br>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Loading and exploring dataset

# %%
df=pd.read_csv("chennai_house_price_prediction.csv")

# %%
df.shape
# Out:
# (7109, 19)

# %%
df.head()
# Out:
#    PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P03210  Karapakkam      1004            131        1.0         1.0       3
# 1  P09411  Anna Nagar      1986             26        2.0         1.0       5
# 2  P01812       Adyar       909             70        1.0         1.0       3
# 3  P05346   Velachery      1855             14        3.0         2.0       5
# 4  P06210  Karapakkam      1226             84        1.0         1.0       3
#
#   SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL  STREET MZZONE  QS_ROOMS  \
# 0  AbNormal        Yes  Commercial        AllPub   Paved      A       4.0
# 1  AbNormal         No  Commercial        AllPub  Gravel     RH       4.9
# 2  AbNormal        Yes  Commercial           ELO  Gravel     RL       4.1
# 3    Family         No      Others       NoSewr    Paved      I       4.7
# 4  AbNormal        Yes      Others        AllPub  Gravel      C       3.0
#
#    QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  SALES_PRICE
# 0          3.9         4.9       4.330  144400      7600000
# 1          4.2         2.5       3.765  304049     21717770
# 2          3.8         2.2       3.090   92114     13159200
# 3          3.9         3.6       4.010   77042      9630290
# 4          2.5         4.1       3.290   74063      7406250

# %% [markdown]
# It is pretty intuitive that <b>PRT_ID</b> is not of any use do let's drop it.<br>
# After that categorise numerical and categorical features

# %%
df.drop(["PRT_ID"],axis=1,inplace=True)

# %%
num_cols=["INT_SQFT","DIST_MAINROAD","N_BEDROOM","N_BATHROOM","N_ROOM","QS_ROOMS","QS_BATHROOM",
          "QS_BEDROOM","QS_OVERALL","COMMIS"]
cat_cols=["AREA","SALE_COND","PARK_FACIL","BUILDTYPE","UTILITY_AVAIL","STREET","MZZONE"]

# %%
df.describe(include="all")
# Out:
#             AREA     INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM  \
# count       7109  7109.000000    7109.000000  7108.000000  7104.000000
# unique        17          NaN            NaN          NaN          NaN
# top     Chrompet          NaN            NaN          NaN          NaN
# freq        1681          NaN            NaN          NaN          NaN
# mean         NaN  1382.073006      99.603179     1.637029     1.213260
# std          NaN   457.410902      57.403110     0.802902     0.409639
# min          NaN   500.000000       0.000000     1.000000     1.000000
# 25%          NaN   993.000000      50.000000     1.000000     1.000000
# 50%          NaN  1373.000000      99.000000     1.000000     1.000000
# 75%          NaN  1744.000000     148.000000     2.000000     1.000000
# max          NaN  2500.000000     200.000000     4.000000     2.000000
#
#              N_ROOM SALE_COND PARK_FACIL BUILDTYPE UTILITY_AVAIL STREET  \
# count   7109.000000      7109       7109      7109          7109   7109
# unique          NaN         9          3         5             5      5
# top             NaN   AdjLand        Yes     House        AllPub  Paved
# freq            NaN      1433       3587      2444          1886   2560
# mean       3.688704       NaN        NaN       NaN           NaN    NaN
# std        1.019099       NaN        NaN       NaN           NaN    NaN
# min        2.000000       NaN        NaN       NaN           NaN    NaN
# 25%        3.000000       NaN        NaN       NaN           NaN    NaN
# 50%        4.000000       NaN        NaN       NaN           NaN    NaN
# 75%        4.000000       NaN        NaN       NaN           NaN    NaN
# max        6.000000       NaN        NaN       NaN           NaN    NaN
#
#        MZZONE     QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL  \
# count    7109  7109.000000  7109.000000  7109.000000  7061.000000
# unique      6          NaN          NaN          NaN          NaN
# top        RL          NaN          NaN          NaN          NaN
# freq     1858          NaN          NaN          NaN          NaN
# mean      NaN     3.517471     3.507244     3.485300     3.503254
# std       NaN     0.891972     0.897834     0.887266     0.527223
# min       NaN     2.000000     2.000000     2.000000     2.000000
# 25%       NaN     2.700000     2.700000     2.700000     3.130000
# 50%       NaN     3.500000     3.500000     3.500000     3.500000
# 75%       NaN     4.300000     4.300000     4.300000     3.890000
# max       NaN     5.000000     5.000000     5.000000     4.970000
#
#                COMMIS   SALES_PRICE
# count     7109.000000  7.109000e+03
# unique            NaN           NaN
# top               NaN           NaN
# freq              NaN           NaN
# mean    141005.726544  1.089491e+07
# std      78768.093718  3.768603e+06
# min       5055.000000  2.156875e+06
# 25%      84219.000000  8.272100e+06
# 50%     127628.000000  1.033505e+07
# 75%     184506.000000  1.299390e+07
# max     495405.000000  2.366734e+07

# %% [markdown]
# ## Univariate analysis

# %% [markdown]
# ### On categorical features

# %%
plt.figure(figsize=(20,5))
sns.countplot(x="AREA",data=df)

# %% [markdown]
# It can be clearly seen that there are some areas which are categorized differently from their group because of spelling erros.<br>
# So let's correct them

# %%
df.replace(["TNagar","Chrompt","Chrmpet","Karapakam","Ana Nagar","Chormpet","Adyr",
           "Velchery","Ann Nagar","KKNagar"],
           ["T Nagar","Chrompet","Chrompet","Karapakkam","Anna Nagar","Chrompet","Adyar",
            "Velachery","Anna Nagar","KK Nagar"],inplace=True)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="AREA",data=df)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="SALE_COND",data=df)

# %% [markdown]
# Here again we can see that there are some spelling errors

# %%
df.replace(["Ab Normal","Partiall","Adj Land","PartiaLl"],["AbNormal","Partial","AdjLand","Partial"],inplace=True)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="SALE_COND",data=df)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="PARK_FACIL",data=df)

# %% [markdown]
# Again spelling errors

# %%
df.replace("Noo","No",inplace=True)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="PARK_FACIL",data=df)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="BUILDTYPE",data=df)

# %% [markdown]
# Again spelling errors

# %%
df.replace(["Comercial","Other"],["Commercial","Others"],inplace=True)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="BUILDTYPE",data=df)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="UTILITY_AVAIL",data=df)

# %% [markdown]
# Spelling errors

# %%
df.replace("All Pub","AllPub",inplace=True)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="UTILITY_AVAIL",data=df)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="STREET",data=df)

# %% [markdown]
# Spelling errors

# %%
df.replace(["Pavd","NoAccess"],["Paved","No Access"],inplace=True)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="STREET",data=df)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="MZZONE",data=df)

# %% [markdown]
# ### For numerical data

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.distplot(df["INT_SQFT"])

plt.subplot(1,2,2)
plt.boxplot(df["INT_SQFT"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x8ce37f0>,
#   <matplotlib.lines.Line2D at 0x8ce3830>],
#  'caps': [<matplotlib.lines.Line2D at 0x8ce3a90>,
#   <matplotlib.lines.Line2D at 0x8ce3f10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x8ce3570>],
#  'medians': [<matplotlib.lines.Line2D at 0x8ce3fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x8cee1f0>],
#  'means': []}

# %% [markdown]
# This data is bimodal so let's normalize it

# %%
plt.figure(figsize=(5,5))
transformed=abs(df["INT_SQFT"] 
                - 1382)
sns.distplot(transformed)

# %%
df["INT_SQFT_NEW"]=transformed

# %%
df.drop("INT_SQFT",axis=1,inplace=True)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.distplot(df["DIST_MAINROAD"])

plt.subplot(1,2,2)
plt.boxplot(df["DIST_MAINROAD"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x93bda50>,
#   <matplotlib.lines.Line2D at 0x93bda90>],
#  'caps': [<matplotlib.lines.Line2D at 0x93bdcf0>,
#   <matplotlib.lines.Line2D at 0x93bdfd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x93bd7d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x93c7410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x93c7450>],
#  'means': []}

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.countplot(df["N_BEDROOM"].dropna())

plt.subplot(1,2,2)
plt.boxplot(df["N_BEDROOM"].dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x93faf10>,
#   <matplotlib.lines.Line2D at 0x93fafd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x94031d0>,
#   <matplotlib.lines.Line2D at 0x9403650>],
#  'boxes': [<matplotlib.lines.Line2D at 0x93fac90>],
#  'medians': [<matplotlib.lines.Line2D at 0x94038d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x9403910>],
#  'means': []}

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.countplot(df["N_BEDROOM"].dropna())

plt.subplot(1,2,2)
plt.boxplot(df["N_BEDROOM"].dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x946f510>,
#   <matplotlib.lines.Line2D at 0x946f550>],
#  'caps': [<matplotlib.lines.Line2D at 0x946f7b0>,
#   <matplotlib.lines.Line2D at 0x946fc30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x946f290>],
#  'medians': [<matplotlib.lines.Line2D at 0x946feb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x946ff70>],
#  'means': []}

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.countplot(df["N_ROOM"])

plt.subplot(1,2,2)
plt.boxplot(df["N_ROOM"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x94dedf0>,
#   <matplotlib.lines.Line2D at 0x94deeb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x94e50b0>,
#   <matplotlib.lines.Line2D at 0x94e5530>],
#  'boxes': [<matplotlib.lines.Line2D at 0x94deb70>],
#  'medians': [<matplotlib.lines.Line2D at 0x94e57b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x94e57f0>],
#  'means': []}

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.distplot(df["QS_ROOMS"])

plt.subplot(1,2,2)
plt.boxplot(df["QS_ROOMS"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x9a62e70>,
#   <matplotlib.lines.Line2D at 0x9a62f30>],
#  'caps': [<matplotlib.lines.Line2D at 0x9a6a130>,
#   <matplotlib.lines.Line2D at 0x9a6a5b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x9a62bf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x9a6a830>],
#  'fliers': [<matplotlib.lines.Line2D at 0x9a6a870>],
#  'means': []}

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.distplot(df["QS_BATHROOM"])

plt.subplot(1,2,2)
plt.boxplot(df["QS_BATHROOM"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb1d8d90>,
#   <matplotlib.lines.Line2D at 0xb1d8dd0>],
#  'caps': [<matplotlib.lines.Line2D at 0xb1e1050>,
#   <matplotlib.lines.Line2D at 0xb1e14d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb1d8b10>],
#  'medians': [<matplotlib.lines.Line2D at 0xb1e1750>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb1e1790>],
#  'means': []}

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.distplot(df["QS_BEDROOM"])

plt.subplot(1,2,2)
plt.boxplot(df["QS_BEDROOM"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb24ed90>,
#   <matplotlib.lines.Line2D at 0xb24edd0>],
#  'caps': [<matplotlib.lines.Line2D at 0xb255050>,
#   <matplotlib.lines.Line2D at 0xb2554b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb24eb10>],
#  'medians': [<matplotlib.lines.Line2D at 0xb255730>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb255770>],
#  'means': []}

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.distplot(df["QS_OVERALL"].dropna())

plt.subplot(1,2,2)
plt.boxplot(df["QS_OVERALL"].dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb2f8270>,
#   <matplotlib.lines.Line2D at 0xb2f82b0>],
#  'caps': [<matplotlib.lines.Line2D at 0xb2f8510>,
#   <matplotlib.lines.Line2D at 0xb2f8990>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb2edfd0>],
#  'medians': [<matplotlib.lines.Line2D at 0xb2f8c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb2f8c50>],
#  'means': []}

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.distplot(df["COMMIS"])

plt.subplot(1,2,2)
plt.boxplot(df["COMMIS"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xb42cdb0>,
#   <matplotlib.lines.Line2D at 0xb42cdf0>],
#  'caps': [<matplotlib.lines.Line2D at 0xb434070>,
#   <matplotlib.lines.Line2D at 0xb4344f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0xb42cb30>],
#  'medians': [<matplotlib.lines.Line2D at 0xb434770>],
#  'fliers': [<matplotlib.lines.Line2D at 0xb4347b0>],
#  'means': []}

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ### For categorical features

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="AREA",y="SALES_PRICE",data=df)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="SALE_COND",y="SALES_PRICE",data=df)

# %% [markdown]
# The feature <b>SALE_COND</b> can  be dropped as it does not vary much for different values

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="PARK_FACIL",y="SALES_PRICE",data=df)

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="BUILDTYPE",y="SALES_PRICE",data=df)

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="UTILITY_AVAIL",y="SALES_PRICE",data=df)

# %% [markdown]
# The feature <b>UTILITY_AVAIL</b> can  be dropped as it does not vary much for different values

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="STREET",y="SALES_PRICE",data=df)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="MZZONE",y="SALES_PRICE",data=df)

# %% [markdown]
# ### For numerical features

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="INT_SQFT_NEW",y="SALES_PRICE",hue="AREA",data=df)

# %% [markdown]
# It is clearly visible that houses of area<b> Anna Nagar</b> and<b> T Nagar</b> have relatively higher price even for small<b> INT_SQFT_NEW</b><br>
# We can divide<b> INT_SQFT_NEW</b> in two columns one  having<b> Anna Nagar</b> and<b> T Nagar</b> and other having all other <b>areas</b>.

# %%
df["INT_SQFT_1"]=df["INT_SQFT_NEW"].copy()
df["INT_SQFT_2"]=df["INT_SQFT_NEW"].copy()

# %%
df.loc[df["AREA"]=="Anna Nagar","INT_SQFT_2"]=0
df.loc[df["AREA"]=="T Nagar","INT_SQFT_2"]=0
df.loc[df["AREA"]!="Anna Nagar","INT_SQFT_1"]=0
df.loc[df["AREA"]=="T Nagar","INT_SQFT_1"]=df.loc[df["AREA"]=="T Nagar","INT_SQFT_NEW"]

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x="DIST_MAINROAD",y="SALES_PRICE",data=df)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x="N_BEDROOM",y="SALES_PRICE",hue="AREA",data=df)

# %% [markdown]
# It is clearly visible that houses of area<b> Velachery</b> and<b> KK Nagar</b> have relatively more no of rooms<br>
# We can divide<b> N_BEDROOM</b> in two columns one  having<b> Velachery</b> and<b> KK Nagar</b> and other having all other <b>AREA</b>.

# %%
df["BEDROOM_1"]=df["N_BEDROOM"].copy()
df["BEDROOM_2"]=df["N_BEDROOM"].copy()

# %%
df.loc[df["AREA"]=="Velachery","BEDROOM_2"]=0
df.loc[df["AREA"]=="KK Nagar","BEDROOM_2"]=0
df.loc[df["AREA"]!="Velachery","BEDROOM_1"]=0
df.loc[df["AREA"]=="KK Nagar","BEDROOM_1"]=df.loc[df["AREA"]=="KK Nagar","N_BEDROOM"]

# %%
sns.scatterplot(x="N_BATHROOM",y="SALES_PRICE",data=df)

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x="N_ROOM",y="SALES_PRICE",hue="AREA",data=df)

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x="QS_ROOMS",y="SALES_PRICE",hue="BUILDTYPE",data=df)

# %%
sns.scatterplot(x="QS_BATHROOM",y="SALES_PRICE",hue="BUILDTYPE",data=df)

# %%
sns.scatterplot(x="QS_BEDROOM",y="SALES_PRICE",hue="BUILDTYPE",data=df)

# %%
sns.scatterplot(x="QS_OVERALL",y="SALES_PRICE",hue="BUILDTYPE",data=df)

# %% [markdown]
# It is clearly visible that we can combined all qulaity scores together as the have high correlation between them<br>
# Will do it later after taking a look at correlation matrix

# %%
sns.scatterplot(x="COMMIS",y="SALES_PRICE",data=df)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x="INT_SQFT_NEW",y="SALES_PRICE",data=df)

# %%
num_cols=["INT_SQFT","DIST_MAINROAD","N_BEDROOM","N_BATHROOM","N_ROOM","QS_ROOMS","QS_BATHROOM",
          "QS_BEDROOM","QS_OVERALL","COMMIS"]
cat_cols=["AREA","SALE_COND","PARK_FACIL","BUILDTYPE","UTILITY_AVAIL","STREET","MZZONE"]

# %% [markdown]
# Now lets's drop <b>INT_SQFT_NEW</b> and <b>N_BEDROOM</b>

# %%
df.drop(["INT_SQFT_NEW","N_BEDROOM"],axis=1,inplace=True)

# %%
for i in ["AREA","SALE_COND","PARK_FACIL","BUILDTYPE","UTILITY_AVAIL","STREET","MZZONE"]:
    dummy= pd.get_dummies(df[i], drop_first= True)
    df= pd.concat([df, dummy], axis= 1)
    df.drop([i],axis= 1, inplace= True)

# %%
df.isnull().sum()
# Out:
# DIST_MAINROAD     0
# N_BATHROOM        5
# N_ROOM            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# COMMIS            0
# SALES_PRICE       0
# INT_SQFT_1        0
# INT_SQFT_2        0
# BEDROOM_1         0
# BEDROOM_2         1
# Anna Nagar        0
# Chrompet          0
# KK Nagar          0
# Karapakkam        0
# T Nagar           0
# Velachery         0
# AdjLand           0
# Family            0
# Normal Sale       0
# Partial           0
# Yes               0
# House             0
# Others            0
# ELO               0
# NoSeWa            0
# NoSewr            0
# No Access         0
# Paved             0
# C                 0
# I                 0
# RH                0
# RL                0
# RM                0
# dtype: int64

# %%
df.dropna(axis=0,how="any",inplace=True)

# %% [markdown]
# Now let's do some feature selection<br>
# I am here applying <b>forward feature selection</b>

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from mlxtend.feature_selection import SequentialFeatureSelector as sfs

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()

# %%
df["QS_FINAL"]=(df["QS_ROOMS"]+df["QS_BATHROOM"]+df["QS_BEDROOM"]+df["QS_OVERALL"])/4
df["BATH_BED"]=df["N_BATHROOM"]+df["N_ROOM"]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df.drop(["SALES_PRICE","QS_ROOMS","QS_BATHROOM",
                            "QS_OVERALL","N_BATHROOM","N_ROOM"],axis=1),df["SALES_PRICE"],random_state=2)

# %%
sfs1=sfs(LR,k_features=30,forward=True,verbose=0,scoring="r2",cv=10)

# %%
sfs1=sfs1.fit(X_train,Y_train)

# %%
print(list(sfs1.k_feature_names_))
# Out:
# ['QS_BEDROOM', 'COMMIS', 'INT_SQFT_1', 'INT_SQFT_2', 'BEDROOM_1', 'Anna Nagar', 'Chrompet', 'KK Nagar', 'Karapakkam', 'T Nagar', 'Velachery', 'AdjLand', 'Family', 'Normal Sale', 'Partial', 'Yes', 'House', 'Others', 'ELO', 'NoSeWa', 'NoSewr ', 'No Access', 'Paved', 'C', 'I', 'RH', 'RL', 'RM', 'QS_FINAL', 'BATH_BED']

# %%
df1=df[list(sfs1.k_feature_names_)].copy()

# %%
LR1=LinearRegression()

# %%
X_train_1,X_test_1,Y_train_1,Y_test_1=train_test_split(df1,df["SALES_PRICE"],random_state=10)

# %%
LR1.fit(X_train_1,Y_train_1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
LR1.predict(X_test_1)
# Out:
# array([ 8154840.60217192,  6655801.72336078, 13000927.48763878, ...,
#        16598413.05311096, 20640439.38963391, 13482777.0673876 ])

# %%
LR1.score(X_test_1,Y_test_1)
# Out:
# 0.9436966242904198

# %% [markdown]
# Our <b>prediction score</b> came out to be 94%
